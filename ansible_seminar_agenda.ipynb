# %% [markdown]
# # Agenda: Dreitägiges Ansible-Seminar

# %% [markdown]
# ## Überblick
#
# **Zielgruppe:** Admins / DevOps / Entwickler mit Linux-/Grundlagenkenntnissen
# **Voraussetzungen:** Laptop mit Linux/macOS oder Windows + WSL, SSH-Zugang zu 2–3 Test-Hosts (VMs/Container)
# **Lernziele:**
# - Ansible-Grundlagen sicher anwenden (Inventory, Playbooks, Module)
# - Strukturierung mit Roles, Variablen, Templates, Vault
# - Debugging/Fehlerbehandlung und Best Practices
# - Einstieg in Windows-Automation, Dynamic Inventory, CI/CD und AAP/AWX

# %% [markdown]
# # Tag 1
#
# ## 🟢 Grundlagen & Architektur
#
# ### 🎯 Lernziel
# Verstehen, wie Ansible funktioniert, und erste Playbooks selbst schreiben.
#
# ### Inhalte
# **Einführung**
# - Was ist Ansible? (Use Cases, Stärken/Schwächen)
# - Agentless-Prinzip: SSH (Linux), WinRM (Windows Targets)
# - Idempotenz & deklarativer Ansatz
# - Architektur: Control Node, Managed Nodes, Inventory
#
#
# **Inventories & Ad-hoc Commands**
# - INI vs YAML Inventory
# - Host-/Group-Variablen
# - Ad-hoc Befehle: `command`, `shell`, `copy`, `service`
#
#
# **Playbooks & Module**
# - YAML-Struktur: Plays, Tasks, Handlers
# - `become` / Privilege Escalation
# - Wichtige Module: `apt`/`yum`, `service`, `copy`, `template`
#
#
# **Variablen, Facts & Templates**
# - Facts (`setup`) und Variablen-Scopes
# - `host_vars` / `group_vars`
# - Jinja2 Templates

# %% [markdown]
# # Tag 2
#
# ## 🟡 Strukturierung & Best Practices
#
# ### 🎯 Lernziel
# Strukturierte, wiederverwendbare Playbooks und Rollen bauen.
#
# ### Inhalte
# **Roles**
# - Warum Roles?
# - Verzeichnisstruktur: `tasks/`, `handlers/`, `templates/`, `defaults/`, `vars/`
# - `defaults` vs `vars`
# - Handlers sauber einsetzen
#
#
# **Ansible Galaxy**
# - Rollen installieren & versionieren
# - Abhängigkeiten (`meta/main.yml`)
# - Eigene Role als internes Template
#
# **Ansible Vault**
# - Secrets verschlüsseln & entschlüsseln
# - Vault Password Files / Umgebungsvariablen
# - Hinweise zur CI/CD Nutzung
#
# **Error Handling & Debugging**
# - `when`, `register`
# - `failed_when`, `changed_when`
# - Check Mode & Diff Mode
# - `debug`, `-vvv`
#
# **Best Practices**
# - Projektstruktur (Repo Layout)
# - Idempotenz-Checks
# - Naming Conventions
# - Performance: Forks, Serial, Rolling Updates (Überblick)

# %% [markdown]
# # Tag 3
#
# ## 🔴 Advanced & Enterprise Use Cases
#
# ### 🎯 Lernziel
# Ansible produktionsreif einsetzen und typische Enterprise-Themen einordnen.
#
# ### Inhalte
# **Windows Automation**
# - WinRM Grundlagen (Concepts)
# - Windows-Module: `win_service`, `win_package`, `win_file`, `win_updates`
# - Unterschiede zu Linux (Pfad/Quoting/Reboots)
#
# **Dynamic Inventory & Cloud**
# - Inventory Plugins (AWS/Azure/vSphere – Überblick)
# - Tag-/Label-basierte Zielgruppen
# - Variable Merging & Host Patterns
#
# **CI/CD Integration**
# - Pipeline-Pattern (GitLab CI/Jenkins)
# - Linting (`ansible-lint`)
# - Testing mit Molecule (Konzept)
#
# **Automation Platform / AWX**
# - Job Templates, Credentials, RBAC
# - Surveys, Projects, Inventories
# - Wann lohnt sich AWX/AAP?
#
# **Abschluss**
# End-to-end Szenario:
# - Webserver + (optionale) DB
# - Secrets via Vault
# - Rollenbasiertes Deployment
# - Pipeline-Run (trocken oder echt)

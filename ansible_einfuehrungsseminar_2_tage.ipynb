# %% [markdown]
# # Agenda: Zweitägiges Ansible-Einführungsseminar

# %% [markdown]
# ## Überblick
#
# **Zielgruppe:** Einsteiger, Admins, DevOps, Entwickler ohne oder mit wenig Ansible-Erfahrung
# **Voraussetzungen:**
# - Grundkenntnisse Linux & SSH
# - Laptop mit Linux/macOS oder Windows + WSL
# - Zugriff auf 2–3 Test-VMs oder Container
#
# **Lernziele:**
# - Ansible-Architektur verstehen
# - Inventories und Ad-hoc Commands anwenden
# - Playbooks schreiben und strukturieren
# - Variablen, Templates und einfache Rollen nutzen
# - Best Practices für kleine Projekte anwenden

# %% [markdown]
# # 🟢 Tag 1 – Grundlagen & erste Automatisierung
#
# ## 🎯 Lernziel
# Grundverständnis von Ansible aufbauen und erste funktionierende Playbooks erstellen.
#
# ---
#
# ## Einführung & Architektur
# - Was ist Ansible?
# - Typische Use Cases (Provisioning, Deployment, Konfigurationsmanagement)
# - Agentless-Prinzip (SSH)
# - Architektur: Control Node, Managed Nodes, Inventory
# - Idempotenz & deklarativer Ansatz
#
#
# ---
#
# ## Inventories & Ad-hoc Commands
# - INI vs YAML Inventory
# - Gruppen und Host-Variablen
# - Ad-hoc Befehle (`command`, `shell`, `copy`, `service`)
#
#
# ## Playbooks verstehen
# - YAML-Grundlagen
# - Struktur eines Playbooks
# - Tasks & Module
# - become / Privilege Escalation
#
# ---
#
# ## Variablen & Templates
# - Variablen definieren
# - host_vars / group_vars
# - Jinja2 Templates
# - Ansible Facts

# %% [markdown]
# # 🟡 Tag 2 – Strukturierung & Praxis
#
# ## 🎯 Lernziel
# Saubere Projektstruktur aufbauen und kleine Automatisierungsprojekte eigenständig umsetzen.
#
# ---
#
# ## Roles
# - Warum Rollen?
# - Verzeichnisstruktur (`tasks/`, `handlers/`, `templates/`, `defaults/`)
# - Wiederverwendbarkeit
#
#
# ---
#
# ## Bedingungen & Fehlerbehandlung
# - `when`
# - `register`
# - `failed_when`
# - `changed_when`
# - Debugging mit `-vvv`
#
# ---
#
# ## Ansible Vault Einführung
# - Secrets verschlüsseln
# - Passwortdateien
# - Nutzung in Playbooks
#
# ---
#
# ## Projektstruktur & Best Practices
# - Empfohlene Verzeichnisstruktur
# - Idempotenz prüfen
# - Naming Conventions
# - Performance-Grundlagen (forks)
#
# ---
#
# ## Ein kleines Projekt
# - Webserver + Konfiguration
# - Rolle verwenden
# - Variablen nutzen
# - Secret via Vault
# - Deployment gegen mehrere Hosts
#
# Reflexion & Q&A

# %% [markdown]
# # 📦 Empfohlene Projektstruktur
#
# ```
# ansible/
#   inventories/
#     dev/
#       hosts.ini
#       group_vars/
#       host_vars/
#   playbooks/
#     site.yml
#   roles/
#     webserver/
#       tasks/main.yml
#       handlers/main.yml
#       templates/
#       defaults/main.yml
#   ansible.cfg
# ```
